# %% [markdown]
# <a href="https://colab.research.google.com/github/sadrac29/LAB-IA/blob/main/LAB3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! wget https://raw.githubusercontent.com/sadrac29/LAB-IA/main/Datos.csv
# Out:
# --2020-12-16 17:28:33--  https://raw.githubusercontent.com/sadrac29/LAB-IA/main/Datos.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 28102 (27K) [text/plain]
# Saving to: ‘Datos.csv.3’
#
# Datos.csv.3         100%[===================>]  27.44K  --.-KB/s    in 0.003s
#
# 2020-12-16 17:28:33 (10.0 MB/s) - ‘Datos.csv.3’ saved [28102/28102]

# %%
import pandas as pd
data = pd.read_csv("Datos.csv.3")
data
# Out:
#      Numero  ... vivienda nueva /vivienda de segunda
# 0         2  ...                                 2.0
# 1         2  ...                                 1.0
# 2         2  ...                                 2.0
# 3         1  ...                                 2.0
# 4         1  ...                                 2.0
# ..      ...  ...                                 ...
# 370       4  ...                                 2.0
# 371       4  ...                                 1.0
# 372       4  ...                                 1.0
# 373       4  ...                                 2.0
# 374       4  ...                                 1.0
#
# [375 rows x 11 columns]

# %%
! wget https://raw.githubusercontent.com/sadrac29/LAB-IA/main/Datos2.csv
# Out:
# --2020-12-16 17:25:13--  https://raw.githubusercontent.com/sadrac29/LAB-IA/main/Datos2.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 812 [text/plain]
# Saving to: ‘Datos2.csv’
#
# Datos2.csv          100%[===================>]     812  --.-KB/s    in 0s
#
# 2020-12-16 17:25:14 (49.4 MB/s) - ‘Datos2.csv’ saved [812/812]

# %%
import pandas as pd
import numpy as np

data2 = pd.read_csv("Datos2.csv")
data2
# Out:
#     usuarios   salarios
# 0           1       2369
# 1           2       2308
# 2           3       2669
# 3           4       2699
# 4           5       1851
# ..        ...        ...
# 95         96       2540
# 96         97       2436
# 97         98       2540
# 98         99       2803
# 99        100       2105
#
# [100 rows x 2 columns]

# %%
from random import choice
descuento = (data2['salarios '] * 0.4)
#print (descuento)
u_aleatorio = choice(descuento)

# %%
ICN = 0.055/12
ICV = 0.015/12

# %%
precioVenta= data['precio de Venta']
#print (precioVenta)

# %%
len(data['vivienda nueva /vivienda de segunda'])
import math
import numpy as np
vec = []
for pos, estado in enumerate(data['vivienda nueva /vivienda de segunda']):
 
  if estado == 2.0:
    de = (ICV * precioVenta[pos])
    nu1 = 1+ICV
    nu = (1 - math.pow((nu1),-360)) 
    p = round(de/nu)
    vec.append(p)
   # vec=np.array(p)
    #print("Valor 2.0 ==> {}".format(p))
  else:
    de = (ICN * precioVenta[pos])
    nu1 = 1+ICN
    nu = 1 - math.pow((nu1),-360)  
    p1 = round(de/nu)
    vec.append(p1)
   # vec=np.array(p1)
    #print("valor 1.0 ==> {}".format(p1))

# %%
print('Usuario seleccionado: ')
print(round(u_aleatorio))
# Out:
# Usuario seleccionado:
# 910.0

# %%
df=pd.DataFrame(data)
comparacion = []
for i in range(374):
 if vec[i] <= u_aleatorio:
   print(df.iloc[i])
   print('')
   comparacion.append(vec[i])
# Out:
# Numero                                            2
# Ubicación                                 Calidonia
# Nombre                                        WHITE
# Disponibilidad                                VENTA
# precio de Venta                              250000
# Precio de Alquiler                              NaN
# Recamaras                                         2
# Baños                                             2
# Dimensión                                       119
# Tipo de vivienda                       APARTAMENTOS
# vivienda nueva /vivienda de segunda               2
# Name: 0, dtype: object
#
# Numero                                            2
# Ubicación                                 Calidonia
# Nombre                                     BAYFRONT
# Disponibilidad                                VENTA
# precio de Venta                              215000
# Precio de Alquiler                              NaN
# Recamaras                                         1
# ...

# %%
import csv
ruta = 'Datos.csv.3'
with open(ruta, newline='',encoding='utf-8') as f:
  c = csv.DictReader(f)
  for r in c:
    print(r['Nombre'])
# Out:
# WHITE
# H2O
# WHITE
# RIVAGE
# WATERS ON THE BAY
# BAYFRONT
# LA ENSENADA
# RIVAGE
# MIRAMAR TORRE 2
# MIRAMAR PLAZA
# RIVAGE
# ARTS & YOO
# MIRAMAR TORRE 2
# MIRAMAR TORRE 2
# WATERS ON THE BAY
# YOO
# BAYFRONT TOWER
# YOO
# YOO
# YACHT CLUB
# YACHT CLUB
# RIVAGE
# WATERS ON THE BAY
# WHITE
# MIRAMAR TORRE 2
# WHITE
# Apartamento JW Marriott
# OCEANAIRE
# PH Oasis on the Bay
# ROYAL PACIFIC
# Aquamare 29-B
# COURTYARD VIEW
# AQUALINA
# DUPONT TOWER
# MYSTIC POINT
# MYSTIC POINT T100
# Punta Roca
# COSTA PACIFICA T100
# OASIS
# AQUALINA
# COSTA PACIFICA T100
# BLUE BAHIA
# BLUE BAHIA
# DUPONT TOWER
# OCEANAIRE
# PH Oceanaire
# SEMI-AMOBLADO + DEPÓSITO DE 11 METROS
# AQUALINA
# COSTA PACIFICA T100
# COSTA PACIFICA T400
# BLUE BAHIA, Distinguido ! Impecable !
# PACIFIC STAR
# PACIFIC POINT TORRE 300
# OCEANAIRE
# OCEAN PARK TORRE 1
# LOFT FOUR 41
# OCEAN DRIVE
# COSTA PACIFICA T400
# OCEAN DRIVE
# OASIS ON THE BAY
# COSTA PACIFICA TORRE T100
# PACIFIC POINT TORRE 300
# ...

# %%
len(comparacion)
# Out:
# 68

# %%
comparacion
# Out:
# [863.0,
#  742.0,
#  759.0,
#  752.0,
#  777.0,
#  897.0,
#  777.0,
#  725.0,
#  859.0,
#  759.0,
#  828.0,
#  656.0,
#  863.0,
#  742.0,
#  759.0,
#  828.0,
#  828.0,
#  794.0,
#  707.0,
#  903.0,
#  759.0,
#  349.0,
#  897.0,
#  569.0,
#  825.0,
#  897.0,
#  621.0,
#  759.0,
#  846.0,
#  897.0,
#  777.0,
#  777.0,
#  777.0,
#  897.0,
#  897.0,
#  880.0,
#  759.0,
#  794.0,
#  449.0,
#  552.0,
#  621.0,
#  828.0,
#  862.0,
#  652.0,
#  725.0,
#  431.0,
#  526.0,
#  759.0,
#  759.0,
#  656.0,
#  683.0,
#  618.0,
#  790.0,
#  466.0,
#  742.0,
#  825.0,
#  893.0,
#  828.0,
#  621.0,
#  887.0,
#  552.0,
#  894.0,
#  552.0,
#  569.0,
#  858.0,
#  642.0,
#  687.0,
#  897.0]
